# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("housing.csv", header=None, sep="\s+")
df.columns = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
df.head(2)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Pável Hernández\AppData\Local\Temp\ipykernel_6600\1607448469.py:1: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv("housing.csv", header=None, sep="\s+")
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
#
#    PTRATIO      B  LSTAT  MEDV
# 0     15.3  396.9   4.98  24.0
# 1     17.8  396.9   9.14  21.6

# %%
# Establecer el estilo
sns.set_theme(style='whitegrid', context='notebook')

# %% [markdown]
# ## Entendiendo los datos

# %% [markdown]
# Ya una vez descargados los datos lo que hay que hacer es entenderlos. Es importante saber que el algoritmo de regresión lineal se basa altamente en correlaciones por lo que se recomienda que comencemos visualizando un gráfico de correlaciones usando *pairplot* de Seaborn

# %%
cols = ['DIS', 'INDUS', 'CRIM', 'RM', 'MEDV']
sns.pairplot(
    data= df[cols],
    height=2.5
)

plt.show()

# %% [markdown]
# Ya una vez visto cómo están correlacionadas las variables de manera visual es importante usar un método numérico para poder entender las correlaciones.

# %%
cm = np.corrcoef(df[cols].values.T)
sns.set_theme(font_scale=1.5)
sns.heatmap(
    cm,
    cbar= True,
    annot= True,
    yticklabels= cols,
    xticklabels= cols,
)
# Out:
# <Axes: >

# %% [markdown]
# En este mapa de calor podemos afirmar que el coeficiente de correlación lineal de las variables 'RM' y 'MEDV' es de 0.7, lo cual la hace una correlación positiva y altamente útil para crear nuestro modelo de regresión lineal con Scikit-Learn
